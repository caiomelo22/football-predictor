# %%
import warnings

from helpers import classification as pf
from helpers.file import save_file
from helpers.options import filtered_cols, selected_stats, strategy

warnings.filterwarnings("ignore")
# Out:
# Setup Complete

# %%
save_pipeline = True
league = "bundesliga"
seasons = "2017-2023"
season_test = 2023
betting_starts_after_n_games = 0

# %%
# Read the data
X_full, y, X_test_full, y_test, odds_test = pf.get_league_data(
    league, seasons, season_test
)
# Out:
#             date  season  home_team       away_team winner
# 1268  2024-01-27    2023   Augsburg   Bayern Munich      A
# 1269  2023-12-16    2023   Augsburg        Dortmund      D
# 1270  2023-12-03    2023   Augsburg  Eint Frankfurt      H
# 1271  2024-02-25    2023   Augsburg        Freiburg      H
# 1272  2023-11-11    2023   Augsburg      Hoffenheim      D
# ...          ...     ...        ...             ...    ...
# 1387  2023-12-09    2023  Wolfsburg        Freiburg      A
# 1388  2024-02-04    2023  Wolfsburg      Hoffenheim      D
# 1389  2024-01-27    2023  Wolfsburg            Köln      D
# 1390  2023-11-25    2023  Wolfsburg      RB Leipzig      H
# 1391  2024-03-02    2023  Wolfsburg       Stuttgart      A
#
# [124 rows x 5 columns]

# %%
# Keep selected columns only
X_train, y_train, X_test = pf.filter_datasets(X_full, y, X_test_full, filtered_cols)

# %%
my_pipeline = pf.simulate(
    X_train, y_train, X_test, y_test, odds_test, betting_starts_after_n_games, strategy, verbose=1
)
# Out:
# Results for model naive_bayes:
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.24      0.30      0.27        33
#            D       0.37      0.47      0.42        40
#            H       0.42      0.25      0.32        51
#
#     accuracy                           0.34       124
#    macro avg       0.34      0.34      0.33       124
# weighted avg       0.36      0.34      0.34       124
#
# Confusion Matrix:
# [[10 12 11]
#  [14 19  7]
#  [18 20 13]]
#
#
# Times when A was predicted: 42 (0.34)
# Times when D was predicted: 51 (0.41)
# Times when H was predicted: 31 (0.25)
#
# Total bets: 100
# Model profit: -213.82411435696207
# Maximum negative sequence:  14
# Maximum positive sequence:  3
# Maximum bet worth: 23.348254500000003
# Minimum bet worth: 8.805650821262978
#
# Results for model knn:
# Classification Report:
#               precision    recall  f1-score   support
#
# ...

# %%
cols_info = {
    "filtered_cols": filtered_cols,
    "selected_stats": selected_stats,
    "strategy": strategy,
}

# Save the pipeline
if save_pipeline:
    path = f"../dist/leagues/{league}/official"
    
    save_file(path, cols_info, 'columns')
    save_file(path, my_pipeline, 'pipeline')
